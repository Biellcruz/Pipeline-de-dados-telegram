# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %% [markdown]
# ![Bot.png](data:image/png;base64,...)

# %%
# Solução do item 1.6.
import json
import requests
from getpass import getpass

# %%
token = getpass()
# Out:
# ··········

# %%
base_url = f'https://api.telegram.org/bot{token}'

# %%
response = requests.get(url=f'{base_url}/getMe')
print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": {
#     "id": 6650335830,
#     "is_bot": true,
#     "first_name": "Cata",
#     "username": "CataEbac_Bot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false
#   }
# }

# %%
response = requests.get(url=f'{base_url}/getUpdates')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 402480837,
#       "message": {
#         "message_id": 20,
#         "from": {
#           "id": 6154979099,
#           "is_bot": false,
#           "first_name": "Gabriel",
#           "last_name": "Cruz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1001740675193,
#           "title": "Projeto Ebac",
#           "type": "supergroup"
#         },
#         "date": 1693968018,
#         "text": "Ola mundo"
#       }
#     },
#     {
#       "update_id": 402480838,
#       "message": {
#         "message_id": 21,
#         "from": {
#           "id": 6154979099,
#           "is_bot": false,
#           "first_name": "Gabriel",
#           "last_name": "Cruz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1001740675193,
#           "title": "Projeto Ebac",
#           "type": "supergroup"
#         },
#         "date": 1693968021,
#         "text": "Teste"
#       }
#     },
#     {
#       "update_id": 402480839,
#       "message": {
#         "message_id": 22,
#         "from": {
#           "id": 6154979099,
#           "is_bot": false,
#           "first_name": "Gabriel",
#           "last_name": "Cruz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1001740675193,
#           "title": "Projeto Ebac",
#           "type": "supergroup"
#         },
#         "date": 1693968034,
#         "photo": [
#           {
#             "file_id": "AgACAgEAAx0CZ8CYeQADFmT35qLm21PYQ9fhqRcbeoIJIenzAAJLrDEbfjzAR7yBErGT1KEqAQADAgADcwADMAQ",
#             "file_unique_id": "AQADS6wxG348wEd4",
#             "file_size": 1061,
#             "width": 90,
#             "height": 49
#           },
#           {
#             "file_id": "AgACAgEAAx0CZ8CYeQADFmT35qLm21PYQ9fhqRcbeoIJIenzAAJLrDEbfjzAR7yBErGT1KEqAQADAgADbQADMAQ",
#             "file_unique_id": "AQADS6wxG348wEdy",
#             "file_size": 15796,
#             "width": 320,
#             "height": 174
#           },
#           {
#             "file_id": "AgACAgEAAx0CZ8CYeQADFmT35qLm21PYQ9fhqRcbeoIJIenzAAJLrDEbfjzAR7yBErGT1KEqAQADAgADeAADMAQ",
#             "file_unique_id": "AQADS6wxG348wEd9",
#             "file_size": 38011,
#             "width": 612,
#             "height": 332
#           }
#         ]
#       }
#     }
#   ]
# }
